# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import control.matlab as ct

G = ct.tf([1000], [1, 25, 100, 0])
ct.sisotool(G)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Clicked at      0.409    +6.037j gain     0.9107 damp    -0.0676
# Clicked at      0.409    +6.037j gain     0.9107 damp    -0.0676
# Clicked at      1.216    -24.63j gain      17.22 damp   -0.04933
# Clicked at     -27.16   -0.1608j gain      4.306 damp          1
# Clicked at     -40.75   +0.6084j gain       30.2 damp     0.9999
# Clicked at      2.908    -15.16j gain      7.225 damp    -0.1884
# Clicked at      7.353    +20.61j gain       17.5 damp     -0.336
# Clicked at      8.137    +27.92j gain       35.5 damp    -0.2798
# Clicked at     -52.78    +2.147j gain      82.05 damp     0.9992
# Clicked at     -20.62   -0.1608j gain     0.1995 damp          1
# Clicked at     -33.43    +1.378j gain      12.63 damp     0.9992
# Clicked at      3.431    +16.76j gain      9.239 damp    -0.2005
# Clicked at      2.647    +12.53j gain      4.715 damp    -0.2066
# ...
